# %%
# !pip install ctgan
# Out:
# Requirement already satisfied: ctgan in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (0.5.0)
# Requirement already satisfied: numpy<2,>=1.20.0 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from ctgan) (1.21.2)
# Requirement already satisfied: scikit-learn<2,>=0.24 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from ctgan) (1.0.1)
# Requirement already satisfied: rdt<0.7,>=0.6.1 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from ctgan) (0.6.1)
# Requirement already satisfied: pandas<2,>=1.1.3 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from ctgan) (1.1.4)
# Requirement already satisfied: packaging<22,>=20 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from ctgan) (21.0)
# Requirement already satisfied: torch<2,>=1.8.0 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from ctgan) (1.10.0+cu102)
# Requirement already satisfied: torchvision<1,>=0.9.0 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from ctgan) (0.11.1+cu102)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from packaging<22,>=20->ctgan) (2.4.7)
# Requirement already satisfied: pytz>=2017.2 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from pandas<2,>=1.1.3->ctgan) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from pandas<2,>=1.1.3->ctgan) (2.8.1)
# Requirement already satisfied: psutil<6,>=5.7 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from rdt<0.7,>=0.6.1->ctgan) (5.8.0)
# Requirement already satisfied: scipy<2,>=1.5.4 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from rdt<0.7,>=0.6.1->ctgan) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn<2,>=0.24->ctgan) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn<2,>=0.24->ctgan) (2.1.0)
# Requirement already satisfied: typing-extensions in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from torch<2,>=1.8.0->ctgan) (3.7.4.3)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from torchvision<1,>=0.9.0->ctgan) (8.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas<2,>=1.1.3->ctgan) (1.15.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (1.1.4)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\katyani\appdata\local\programs\python\python39\lib\site-packages)

# %%
import pandas as pd

# %%
census_df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)

# load test dataset --> skip first row since it's apparently weird
census_df_test = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test', header=None, skiprows=1) 

census_df.columns = census_df_test.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 
                     'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']
columns = census_df.columns

census_df.drop(['fnlwgt'], axis=1, inplace=True)
census_df_test.drop(['fnlwgt'], axis=1, inplace=True)

census_df
# Out:
#        age          workclass    education  education_num  \
# 0       39          State-gov    Bachelors             13
# 1       50   Self-emp-not-inc    Bachelors             13
# 2       38            Private      HS-grad              9
# 3       53            Private         11th              7
# 4       28            Private    Bachelors             13
# ...    ...                ...          ...            ...
# 32556   27            Private   Assoc-acdm             12
# 32557   40            Private      HS-grad              9
# 32558   58            Private      HS-grad              9
# 32559   22            Private      HS-grad              9
# 32560   52       Self-emp-inc      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 14 columns]

# %%
from ctgan import CTGANSynthesizer


# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital_status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native_country',
    'income'
]

ctgan = CTGANSynthesizer(epochs=10)
ctgan.fit(census_df, discrete_columns)

# Synthetic copy
# Out:
# C:\Users\Katyani\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\mixture\_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# C:\Users\Katyani\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\mixture\_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# C:\Users\Katyani\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\mixture\_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# C:\Users\Katyani\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\mixture\_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# C:\Users\Katyani\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\mixture\_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(

# %%
samples = ctgan.sample(32561)

samples.to_csv(r'C:\Users\Katyani\ctgannew2.csv')
